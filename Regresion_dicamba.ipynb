# %% [markdown]
# ## Modelo de Regresión Dicamba

# %% [markdown]
# ### Se importan las librerias

# %%
# Se importan las librerias
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
#from matplotlib import cm

# Modelos de Regresión: árbol de regresión, SVR y KNN
# Se importa la libreria de árbol de regresión
from sklearn.tree import DecisionTreeRegressor 
# Se importa la libreria de SVR
from sklearn.svm import SVR
# Se importa la libreria de KNN de regresión
from sklearn.neighbors import KNeighborsRegressor

# Modelos de Regresión (ensamble): Random Forest, Gradient Boosting, Ada Boost
# Se importa la libreria de Random Forest
from sklearn.ensemble import RandomForestRegressor
# Se importa la libreria de Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor
# Se importa la libreria de Ada Boost
from sklearn.ensemble import AdaBoostRegressor

# Se importa la libreria para dividir los datos de entrenamiento y de pruebas
from sklearn.model_selection import train_test_split
# Se importa la libreria para la métrica R cuadrado y RMSE 
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# ### Se cargan los datos

# %%
data = pd.read_csv("data/data_all_dicamba.csv", sep=";")

data
# Out:
#               date date(m/d/y)   time  day  concentration  \
# 0    3/11/05 11:25     3/11/05  11.25    1            0.0
# 1    3/11/05 11:26     3/11/05  11.26    1            0.0
# 2    3/11/05 11:27     3/11/05  11.27    1            0.0
# 3    3/11/05 11:28     3/11/05  11.28    1            0.0
# 4    3/11/05 11:29     3/11/05  11.29    1            0.0
# ..             ...         ...    ...  ...            ...
# 631  3/15/05 17:16     3/15/05  17.16    2            2.6
# 632  3/15/05 17:17     3/15/05  17.17    2            2.6
# 633  3/15/05 17:18     3/15/05  17.18    2            2.6
# 634  3/15/05 17:19     3/15/05  17.19    2            2.6
# 635  3/15/05 17:20     3/15/05  17.20    2            2.6
#
#      chloride_80ft(mg/L)  chloride_1100ft(mg/L)  CL2_80ft(PPM)  \
# 0                  25.24                  30.37           1.16
# 1                  25.24                  30.38           1.16
# 2                  25.23                  30.38           1.16
# 3                  25.23                  30.41           1.16
# 4                  25.25                  30.40           1.16
# ..                   ...                    ...            ...
# 631                29.62                  36.51           1.11
# 632                29.64                  36.53           1.11
# 633                29.64                  36.56           1.10
# 634                29.57                  36.54           1.10
# 635                29.67                  36.53           1.11
#
#      CL2_1100ft(PPM)  DO_YSI_80ft(mg/L)  ...  FreeClorine_ATI_80ft(PPM)  \
# 0               1.17              11.81  ...                       1.06
# 1               1.18              11.81  ...                       1.06
# 2               1.18              11.81  ...                       1.05
# 3               1.17              11.80  ...                       1.05
# 4               1.18              11.80  ...                       1.05
# ..               ...                ...  ...                        ...
# 631             1.13              12.09  ...                       1.00
# 632             1.13              12.10  ...                       1.00
# 633             1.13              12.10  ...                       1.00
# 634             1.12              12.08  ...                       1.00
# 635             1.12              12.11  ...                       1.00
#
#      FreeClorine_ATI_1100ft(PPM)  ORP_YSI_80ft(mV)  ORP_YSI_1100ft(mV)  \
# 0                           0.99               675                 736
# 1                           0.99               675                 736
# 2                           0.99               675                 736
# 3                           0.99               675                 736
# 4                           0.99               675                 736
# ..                           ...               ...                 ...
# 631                         0.92               670                 740
# 632                         0.92               670                 740
# 633                         0.92               670                 740
# 634                         0.92               670                 740
# 635                         0.92               670                 740
#
#      pH_YSI_80ft  pH_YSI_1100ft  sp_cond_YSI_80ft(µS/cm)  \
# 0           8.76           8.84                      339
# 1           8.76           8.84                      339
# 2           8.76           8.84                      339
# 3           8.76           8.84                      339
# 4           8.76           8.84                      339
# ..           ...            ...                      ...
# 631         8.70           8.83                      349
# 632         8.71           8.83                      349
# 633         8.70           8.84                      349
# 634         8.70           8.84                      349
# 635         8.69           8.84                      349
#
#      sp_cond_YSI_1100ft(µS/cm)  turbidity_YSI_80ft(NTU+)  \
# 0                          338                       0.5
# 1                          338                       0.5
# 2                          338                       0.6
# 3                          338                       0.6
# 4                          338                       0.5
# ..                         ...                       ...
# 631                        348                       0.5
# 632                        348                       0.5
# 633                        348                       0.5
# 634                        348                       0.5
# 635                        348                       0.5
#
#      turbidity_YSI_1100ft(NTU+)
# 0                          -0.7
# 1                          -0.7
# 2                          -0.7
# 3                          -0.7
# 4                          -0.7
# ..                          ...
# 631                        -0.7
# 632                        -0.7
# 633                        -0.7
# 634                        -0.7
# 635                        -0.7
#
# [636 rows x 21 columns]

# %% [markdown]
# ### Preprocesamiento

# %%
# Se buscan registros NaN para eliminarlos
print('Columna                Cantidad NaN')
print(data.isnull().sum(axis = 0))
print(data.shape)
# Out:
# Columna                Cantidad NaN
# date                           0
# date(m/d/y)                    0
# time                           0
# day                            0
# concentration                  0
# chloride_80ft(mg/L)            0
# chloride_1100ft(mg/L)          0
# CL2_80ft(PPM)                  0
# CL2_1100ft(PPM)                0
# DO_YSI_80ft(mg/L)              0
# DO_YSI_1100ft(mg/L)            0
# FreeClorine_ATI_80ft(PPM)      0
# FreeClorine_ATI_1100ft(PPM)    0
# ORP_YSI_80ft(mV)               0
# ORP_YSI_1100ft(mV)             0
# pH_YSI_80ft                    0
# pH_YSI_1100ft                  0
# sp_cond_YSI_80ft(µS/cm)        0
# sp_cond_YSI_1100ft(µS/cm)      0
# turbidity_YSI_80ft(NTU+)       0
# turbidity_YSI_1100ft(NTU+)     0
# dtype: int64
# (636, 21)

# %%
# Se eliminan los registros NaN del DataFrame
#data = data.dropna()

# %%
# Se genera las estadísticas del DataFrame
data.describe()
# Out:
#              time         day  concentration  chloride_80ft(mg/L)  \
# count  636.000000  636.000000     636.000000           636.000000
# mean    13.926572    1.500000       1.108491            27.425692
# std      1.956364    0.500394       0.957370             2.157185
# min     10.150000    1.000000       0.000000            25.160000
# 25%     12.177500    1.000000       0.000000            25.270000
# 50%     14.325000    1.500000       0.800000            27.300000
# 75%     15.410000    2.000000       1.300000            29.590000
# max     17.200000    2.000000       2.600000            29.790000
#
#        chloride_1100ft(mg/L)  CL2_80ft(PPM)  CL2_1100ft(PPM)  \
# count             636.000000     636.000000       636.000000
# mean               33.394733       1.142987         1.158286
# std                 3.539450       0.032751         0.030327
# min                29.410000       1.100000         1.110000
# 25%                29.877500       1.110000         1.130000
# 50%                33.380000       1.140000         1.150000
# 75%                36.760000       1.170000         1.180000
# max                38.080000       1.200000         1.220000
#
#        DO_YSI_80ft(mg/L)  DO_YSI_1100ft(mg/L)  FreeClorine_ATI_80ft(PPM)  \
# count         636.000000           636.000000                 636.000000
# mean           11.916682             8.685283                   1.030849
# std             0.093754             2.757132                   0.020966
# min            11.780000             5.850000                   1.000000
# 25%            11.830000             5.900000                   1.010000
# 50%            11.895000             8.710000                   1.035000
# 75%            12.000000            11.440000                   1.050000
# max            12.130000            11.490000                   1.060000
#
#        FreeClorine_ATI_1100ft(PPM)  ORP_YSI_80ft(mV)  ORP_YSI_1100ft(mV)  \
# count                   636.000000        636.000000          636.000000
# mean                      0.947799        677.874214          740.628931
# std                       0.032262          7.031754            5.604614
# min                       0.680000        669.000000          727.000000
# 25%                       0.940000        672.000000          738.000000
# 50%                       0.940000        675.000000          740.000000
# 75%                       0.960000        686.000000          745.000000
# max                       1.010000        695.000000          751.000000
#
#        pH_YSI_80ft  pH_YSI_1100ft  sp_cond_YSI_80ft(µS/cm)  \
# count   636.000000     636.000000               636.000000
# mean      8.707138       8.813160               343.201258
# std       0.027920       0.029187                 5.026268
# min       8.620000       8.720000               338.000000
# 25%       8.690000       8.790000               338.000000
# 50%       8.710000       8.820000               343.500000
# 75%       8.720000       8.830000               348.000000
# max       8.770000       8.850000               349.000000
#
#        sp_cond_YSI_1100ft(µS/cm)  turbidity_YSI_80ft(NTU+)  \
# count                 636.000000                636.000000
# mean                  342.273585                  0.553459
# std                     5.131713                  0.054735
# min                   336.000000                  0.400000
# 25%                   337.000000                  0.500000
# 50%                   342.500000                  0.600000
# 75%                   347.000000                  0.600000
# max                   348.000000                  0.700000
#
#        turbidity_YSI_1100ft(NTU+)
# count                  636.000000
# mean                    -0.701730
# std                      0.013047
# min                     -0.800000
# 25%                     -0.700000
# 50%                     -0.700000
# 75%                     -0.700000
# max                     -0.700000

# %% [markdown]
# ### Predicción: Todas las características

# %%
# Se definen los valores de las características:
features = ['chloride_80ft(mg/L)','chloride_1100ft(mg/L)',
            'CL2_80ft(PPM)', 'CL2_1100ft(PPM)',
            'DO_YSI_80ft(mg/L)','DO_YSI_1100ft(mg/L)',
            'FreeClorine_ATI_80ft(PPM)','FreeClorine_ATI_1100ft(PPM)',
            'ORP_YSI_80ft(mV)','ORP_YSI_1100ft(mV)',
            'pH_YSI_80ft','pH_YSI_1100ft',
            'sp_cond_YSI_80ft(µS/cm)','sp_cond_YSI_1100ft(µS/cm)',
            'turbidity_YSI_80ft(NTU+)','turbidity_YSI_1100ft(NTU+)']
                   
X = data[features]
# Variable Objetivo: grade
y = data['concentration']

# Se dividen los datos para el entrenamiento (80% entrenamiento y 20% pruebas)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 1)

# Se crea el modelo
arbol_regresion = DecisionTreeRegressor() 
  
# Se entrena el modelo
arbol_regresion.fit(X_train, y_train)

predicciones = arbol_regresion.predict(X = X_test)

# Se utiliza la métrica: R2
print('R2-árbol de regresión:',  r2_score(y_test, predicciones))

# Se utiliza la métrica: raíz del error cuadrático medio (rmse)
rmse = mean_squared_error( y_true  = y_test, y_pred  = predicciones, squared = False)

print('RMSE-árbol de regresión:', rmse)

# Se utiliza la métrica: MAE
mae = mean_absolute_error(y_test, predicciones)

print('MAE-árbol de regresión:', mae)
# Out:
# R2-árbol de regresión: 0.8147026319020916
# RMSE-árbol de regresión: 0.4205186529751089
# MAE-árbol de regresión: 0.1531250000000002

# %% [markdown]
# ### Se extraen las mejores características (Best Features)

# %%
# Se extraen las mejores características para le modelo
best_features = pd.DataFrame({'feature':X_train.columns,'Importancia':np.round(arbol_regresion.feature_importances_,3)})
best_features = best_features.sort_values('Importancia',ascending=False).set_index('feature')
best_features.head()
# Out:
#                              Importancia
# feature
# FreeClorine_ATI_1100ft(PPM)        0.373
# CL2_80ft(PPM)                      0.156
# chloride_1100ft(mg/L)              0.121
# FreeClorine_ATI_80ft(PPM)          0.115
# DO_YSI_1100ft(mg/L)                0.048

# %%
# Eli5
from eli5 import show_weights

show_weights(arbol_regresion, feature_names = features)
# Out:
# 2023-03-30 11:21:15.812862: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/eli5/sklearn/treeinspect.py:64: RuntimeWarning: invalid value encountered in divide
#   value_ratio=list(value / value.sum()),
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3734
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FreeClorine_ATI_1100ft(PPM)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1564
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CL2_80ft(PPM)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1210
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 chloride_1100ft(mg/L)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1153
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FreeClorine_ATI_80ft(PPM)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0482
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DO_YSI_1100ft(mg/L)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0425
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ORP_YSI_1100ft(mV)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0359
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pH_YSI_80ft
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0283
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DO_YSI_80ft(mg/L)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0186
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CL2_1100ft(PPM)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0182
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 chloride_80ft(mg/L)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ORP_YSI_80ft(mV)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0162
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 turbidity_YSI_80ft(NTU+)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sp_cond_YSI_80ft(µS/cm)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 turbidity_YSI_1100ft(NTU+)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pH_YSI_1100ft
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sp_cond_YSI_1100ft(µS/cm)
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <br>
#         <pre>FreeClorine_ATI_1100ft(PPM) <= 0.935  (20.3%)
#     DO_YSI_1100ft(mg/L) <= 11.405  (15.9%)
#         chloride_1100ft(mg/L) <= 36.970  (14.4%)
#             chloride_80ft(mg/L) <= 25.200  (0.6%)
#                 ORP_YSI_80ft(mV) <= 690.500  (0.4%)  ---> 0.65
#                 ORP_YSI_80ft(mV) > 690.500  (0.2%)  ---> 2.6
#             chloride_80ft(mg/L) > 25.200  (13.8%)
#                 chloride_80ft(mg/L) <= 25.290  (2.6%)
#                     ORP_YSI_80ft(mV) <= 687.000  (0.6%)  ---> 1.3
#                     ORP_YSI_80ft(mV) > 687.000  (2.0%)  ---> 2.6000000000000005
#                 chloride_80ft(mg/L) > 25.290  (11.2%)
#                     FreeClorine_ATI_80ft(PPM) <= 1.005  (6.1%)  ---> 2.599999999999999
#                     FreeClorine_ATI_80ft(PPM) > 1.005  (5.1%)
#                         chloride_1100ft(mg/L) <= 29.435  (0.2%)  ---> 2.6
#                         chloride_1100ft(mg/L) > 29.435  (4.9%)  ---> 2.6000000000000005
#         chloride_1100ft(mg/L) > 36.970  (1.6%)  ---> 0.7999999999999999
#     DO_YSI_1100ft(mg/L) > 11.405  (4.3%)
#         chloride_1100ft(mg/L) <= 29.580  (0.8%)  ---> 2.6
#         chloride_1100ft(mg/L) > 29.580  (3.5%)
#             DO_YSI_80ft(mg/L) <= 11.815  (0.2%)  ---> 2.6
#             DO_YSI_80ft(mg/L) > 11.815  (3.3%)

# %% [markdown]
# ### --------------------------------
#
# ### Se crea el set de entrenamiento y de pruebas
#
# #### Mejores Carácterísticas, sin ajuste de hiperparámetros

# %%
# Se utilizan las mejores carácteristicas
X = data[['FreeClorine_ATI_1100ft(PPM)','CL2_80ft(PPM)',
          'chloride_1100ft(mg/L)', 'FreeClorine_ATI_80ft(PPM)',
          'DO_YSI_1100ft(mg/L)']]
# Variable Objetivo: grade
y = data['concentration']

# Se dividen los datos para el entrenamiento (80% entrenamiento y 20% pruebas)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size = 0.8,
                                                    random_state=1)

# %% [markdown]
# #### DecisionTreeRegressor

# %%
# Se crea el modelo
DTR = DecisionTreeRegressor() 
  
# Se entrena el modelo
DTR.fit(X_train, y_train)

predictDTR = DTR.predict(X = X_test)

#R2
r2DTR= r2_score(y_test, predictDTR)

#RMSE
rmseDTR = mean_squared_error(y_true = y_test, y_pred = predictDTR, squared=False)

#MAE
maeDTR = mean_absolute_error(y_test, predictDTR)

print('R2 = %.2f' % r2DTR)
print('RMSE = %.2f' % rmseDTR)
print('MAE = %.2f' % maeDTR)
# Out:
# R2 = 0.62
# RMSE = 0.60
# MAE = 0.23

# %% [markdown]
# #### SVR

# %%
# Se crea el modelo
modelo_svr = SVR()

# Se entrena el modelo
modelo_svr.fit(X_train, y_train)

predictSVR = modelo_svr.predict(X_test)

#R2
r2SVR= r2_score(y_test, predictSVR)

#RMSE
rmseSVR = mean_squared_error(y_true = y_test, y_pred = predictSVR, squared=False)

#MAE
maeSVR = mean_absolute_error(y_test, predictSVR)

print('R2 = %.2f' % r2SVR)
print('RMSE = %.2f' % rmseSVR)
print('MAE = %.2f' % maeSVR)
# Out:
# R2 = 0.01
# RMSE = 0.97
# MAE = 0.77

# %% [markdown]
# #### KNN Regressor

# %%
# Se crea el modelo
KNN = KNeighborsRegressor()

KNN = KNN.fit(X_train, y_train)

predictKNN = KNN.predict(X = X_test)

#R2
r2KNN= r2_score(y_test, predictKNN)

#RMSE
rmseKNN = mean_squared_error(y_true = y_test, y_pred = predictKNN, squared=False)

#MAE
maeKNN = mean_absolute_error(y_test, predictKNN)

print('R2 = %.2f' % r2KNN)
print('RMSE = %.2f' % rmseKNN)
print('MAE = %.2f' % maeKNN)
# Out:
# R2 = 0.86
# RMSE = 0.36
# MAE = 0.17

# %% [markdown]
# #### --------------- Algoritmos de Emsamble ---------------

# %% [markdown]
# #### RandomForestRegressor

# %%
# Se crea el modelo
RFR = RandomForestRegressor()
  
# Se entrena el modelo
RFR.fit(X_train, y_train)

predictRFR = RFR.predict(X = X_test)

#R2
r2RFR= r2_score(y_test, predictRFR)

#RMSE
rmseRFR = mean_squared_error(y_true = y_test, y_pred = predictRFR, squared=False)

#MAE
maeRFR = mean_absolute_error(y_test, predictRFR)

print('R2 = %.2f' % r2RFR)
print('RMSE = %.2f' % rmseRFR)
print('MAE = %.2f' % maeRFR)
# Out:
# R2 = 0.83
# RMSE = 0.40
# MAE = 0.19

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
# Se crea el modelo
GB =GradientBoostingRegressor().fit(X_train, y_train)

predictGB = GB.predict(X = X_test)

#R2
r2GB= r2_score(y_test, predictGB)

#RMSE
rmseGB = mean_squared_error(y_true = y_test, y_pred = predictGB, squared=False)

#MAE
maeGB = mean_absolute_error(y_test, predictGB)

print('R2 = %.2f' % r2GB)
print('RMSE = %.2f' % rmseGB)
print('MAE = %.2f' % maeGB)
# Out:
# R2 = 0.85
# RMSE = 0.38
# MAE = 0.24

# %% [markdown]
# #### Ada Boost Regressor

# %%
# Se crea el modelo
AB = AdaBoostRegressor().fit(X_train, y_train)

predictAB = AB.predict(X = X_test)

#R2
r2AB= r2_score(y_test, predictAB)

#RMSE
rmseAB = mean_squared_error(y_true = y_test, y_pred = predictAB, squared=False)

#MAE
maeAB = mean_absolute_error(y_test, predictAB)

print('R2 = %.2f' % r2AB)
print('RMSE = %.2f' % rmseAB)
print('MAE = %.2f' % maeAB)
# Out:
# R2 = 0.72
# RMSE = 0.52
# MAE = 0.40

# %% [markdown]
# ### ------------------------------------------------------------------------------
#
# ###  ***** Ajuste de Hiperparámetros *****
#
# ### ------------------------------------------------------------------------------

# %% [markdown]
# ##### DecisionTreeRegressor

# %%
# DecisionTreeRegressor: Ajuste Hiperparámetros (Random Search)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

dtr_ah = DecisionTreeRegressor()

# 
criterion = ["squared_error", "friedman_mse", "absolute_error", "poisson"]
# 
splitter = ["best", "random"]
#
max_depth = [2, 5, 10, 15, 20]
#
min_samples_split = [2, 5, 10, 15, 20]
#
min_samples_leaf = [1, 2, 4, 6]


grid = dict(criterion = criterion,
            splitter = splitter,
            max_depth = max_depth,
            min_samples_split = min_samples_split,
            min_samples_leaf = min_samples_leaf
           )

#print("[INFO] grid searching over the hyperparameters...")
cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator= dtr_ah,
                                  n_jobs=-1,
                                  cv=cvFold,
                                  param_distributions=grid,
                                  scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train.ravel())

# extract the best model and evaluate it
#print("[INFO] evaluating...")
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

# Se crea un objeto con los mejores ajustes de Hiperparámetros
DTR_AH = bestModel
  
# Se entrena el modelo con los mejores parámetros
DTR_AH.fit(X_train, y_train)

predictDTR_AH = DTR_AH.predict(X = X_test)

#R2
r2DTR_AH= r2_score(y_test, predictDTR_AH)

#RMSE
rmseDTR_AH = mean_squared_error(y_true = y_test, y_pred = predictDTR_AH, squared=False)

#MAE
maeDTR_AH = mean_absolute_error(y_test, predictDTR_AH)

print('R2 = %.2f' % r2DTR_AH)
print('RMSE = %.2f' % rmseDTR_AH)
print('MAE = %.2f' % maeDTR_AH)
# Out:
# Best Parameters (RandomSearch): DecisionTreeRegressor(criterion='poisson', max_depth=15, min_samples_leaf=6,
#                       min_samples_split=10, splitter='random')
# -----------------------------------------------------------
# R2 = 0.72
# RMSE = 0.51
# MAE = 0.30

# %% [markdown]
# ##### SVR

# %%
# SVR: Ajuste Hiperparámetros (Random Search)

from scipy.stats import loguniform

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

svr = SVR()
kernel = ["linear", "rbf", "sigmoid", "poly"]
tolerance = loguniform(1e-6, 1e-3)
C = [1, 1.5, 2, 2.5, 3]
grid = dict(kernel=kernel, tol=tolerance, C=C)

cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator= svr, n_jobs=-1,
	cv=cvFold, param_distributions=grid,
	scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train)

# extract the best model and evaluate it
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

# Se crea un objeto con los mejores ajustes de Hiperparámetros
SVR_AH = bestModel

# Se entrena el modelo con los mejores parámetros
SVR_AH.fit(X_train, y_train)

predictSVR_AH = SVR_AH.predict(X_test)

#R2
r2SVR_AH= r2_score(y_test, predictSVR_AH)

#RMSE
rmseSVR_AH = mean_squared_error(y_true = y_test, y_pred = predictSVR_AH, squared=False)

#MAE
maeSVR_AH = mean_absolute_error(y_test, predictSVR_AH)

print('R2 = %.2f' % r2SVR_AH)
print('RMSE = %.2f' % rmseSVR_AH)
print('MAE = %.2f' % maeSVR_AH)
# Out:
# Best Parameters (RandomSearch): SVR(C=2.5, tol=1.2530597816342301e-06)
# -----------------------------------------------------------
# R2 = 0.68
# RMSE = 0.55
# MAE = 0.34

# %% [markdown]
# #### KNN Regressor

# %%
# KNN-Regressor: Ajuste Hiperparámetros (Random Search)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsRegressor()

# 
n_neighbors = [1, 2, 5, 10]
# 
weights = ["uniform", "distance"]
#
algorithm = ["auto", "ball_tree", "kd_tree", "brute"]
#
leaf_size = [5, 10, 20, 30, 40, 50]
#
p = [2]

grid = dict(n_neighbors = n_neighbors,
            weights = weights,
            algorithm = algorithm,
            leaf_size = leaf_size,
            p = p
           )

#print("[INFO] grid searching over the hyperparameters...")
cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator=knn,
                                  n_jobs=-1,
                                  cv=cvFold,
                                  param_distributions=grid,
                                  scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train.ravel())

# extract the best model and evaluate it
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

knn = bestModel

knn = knn.fit(X_train, y_train)

predictKNN = knn.predict(X = X_test)

#R2
r2KNN= r2_score(y_test, predictKNN)

#RMSE
rmseKNN = mean_squared_error(y_true = y_test, y_pred = predictKNN, squared=False)

#MAE
maeKNN = mean_absolute_error(y_test, predictKNN)

print('R2 = %.2f' % r2KNN)
print('RMSE = %.2f' % rmseKNN)
print('MAE = %.2f' % maeKNN)
# Out:
# Best Parameters (RandomSearch): KNeighborsRegressor(algorithm='kd_tree', leaf_size=10)
# -----------------------------------------------------------
# R2 = 0.86
# RMSE = 0.37
# MAE = 0.17

# %% [markdown]
# #### --------------- Algoritmos de Emsamble ---------------

# %% [markdown]
# ##### RamdomForestRegressor

# %%
# RamdomForestRegressor: Ajuste Hiperparámetros (Random Search)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

rfr = RandomForestRegressor()

# Número de árboles en un bosque aleatorio
n_estimators = [int(x) for x in np.linspace(start=20, stop=200, num = 10)]
# Número de características a considerar en cada división
max_features = [1.0]
# Número máximo de niveles en el árbol
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Número mínimo de muestras requeridas para dividir un nodo
min_samples_split = [2, 5, 10, 15, 20]
# Número mínimo de muestras requeridas en cada nodo hoja
min_samples_leaf = [1, 2, 4, 6]
# Método de selección de muestras para entrenar cada árbol 
bootstrap = [True, False]
grid = dict(n_estimators=n_estimators,
            max_features=max_features,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            bootstrap=bootstrap)

cvFold = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator= rfr,
                                  n_jobs=-1,
                                  cv=cvFold,
                                  param_distributions=grid,
                                  scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train.ravel())


# extract the best model and evaluate it
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

# Se crea un objeto con los mejores ajustes de Hiperparámetros
RFR_AH = bestModel

# Se entrena el modelo
RFR_AH.fit(X_train, y_train)

# Se entrena el modelo con los mejores parámetros
predictRFR_AH = RFR_AH.predict(X = X_test)

#R2
r2RFR_AH= r2_score(y_test, predictRFR_AH)

#RMSE
rmseRFR_AH = mean_squared_error(y_true = y_test, y_pred = predictRFR_AH, squared=False)

#MAE
maeRFR_AH = mean_absolute_error(y_test, predictRFR_AH)

print('R2 = %.2f' % r2RFR_AH)
print('RMSE = %.2f' % rmseRFR_AH)
print('MAE = %.2f' % maeRFR_AH)
# Out:
# Best Parameters (RandomSearch): RandomForestRegressor(max_depth=110, max_features=1.0, min_samples_split=10,
#                       n_estimators=180)
# -----------------------------------------------------------
# R2 = 0.87
# RMSE = 0.36
# MAE = 0.19

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
# GradientBoostingRegressor: Ajuste Hiperparámetros (Random Search)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

gb = GradientBoostingRegressor()

# 
loss = ["squared_error", "absolute_error", "huber", "quantile"]
# 
learning_rate = [0.1]
#
n_estimators = [10, 50, 100, 200]
#
subsample = [1.0]
#
criterion = ["friedman_mse", "squared_error"]
#
min_samples_split = [2]
#
min_samples_leaf = [1]
#
max_depth = [3]

grid = dict(loss = loss,
            learning_rate = learning_rate,
            n_estimators = n_estimators,
            subsample = subsample,
            criterion = criterion,
            min_samples_split = min_samples_split,
            min_samples_leaf = min_samples_leaf,
            max_depth = max_depth)

#print("[INFO] grid searching over the hyperparameters...")
cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator=gb,
                                  n_jobs=-1,
                                  cv=cvFold,
                                  param_distributions=grid,
                                  scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train.ravel())

# extract the best model and evaluate it
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

GB = bestModel.fit(X_train, y_train)

predictGB = GB.predict(X = X_test)

#R2
r2GB= r2_score(y_test, predictGB)

#RMSE
rmseGB = mean_squared_error(y_true = y_test, y_pred = predictGB, squared=False)

#MAE
maeGB = mean_absolute_error(y_test, predictGB)

print('R2 = %.2f' % r2GB)
print('RMSE = %.2f' % rmseGB)
print('MAE = %.2f' % maeGB)
# Out:
# Best Parameters (RandomSearch): GradientBoostingRegressor(criterion='squared_error', loss='huber',
#                           n_estimators=50)
# -----------------------------------------------------------
# R2 = 0.86
# RMSE = 0.37
# MAE = 0.24

# %% [markdown]
# #### Ada Boost Regressor

# %%
# AdaBoostRegressor: Ajuste Hiperparámetros (Random Search)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

ab = AdaBoostRegressor()

# 
n_estimators = [10, 20, 30, 40, 50]
# 
learning_rate = [1.0]
#
loss = ["linear", "square", "exponential"]

grid = dict(n_estimators = n_estimators,
            learning_rate = learning_rate,
            loss = loss)

#print("[INFO] grid searching over the hyperparameters...")
cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
randomSearch = RandomizedSearchCV(estimator=ab,
                                  n_jobs=-1,
                                  cv=cvFold,
                                  param_distributions=grid,
                                  scoring="neg_mean_squared_error")
searchResults = randomSearch.fit(X_train, y_train.ravel())

# extract the best model and evaluate it
bestModel = searchResults.best_estimator_

print("Best Parameters (RandomSearch):", bestModel)
print("-----------------------------------------------------------")

AB = bestModel.fit(X_train, y_train)

predictAB = AB.predict(X = X_test)

#R2
r2AB= r2_score(y_test, predictAB)

#RMSE
rmseAB = mean_squared_error(y_true = y_test, y_pred = predictAB, squared=False)

#MAE
maeAB = mean_absolute_error(y_test, predictAB)

print('R2 = %.2f' % r2AB)
print('RMSE = %.2f' % rmseAB)
print('MAE = %.2f' % maeAB)
# Out:
# Best Parameters (RandomSearch): AdaBoostRegressor(loss='exponential', n_estimators=10)
# -----------------------------------------------------------
# R2 = 0.74
# RMSE = 0.50
# MAE = 0.39

# %% [markdown]
# # -------------------------------------------------------------------------

# %% [markdown]
# ### REGRESIÓN LINEAL

# %%
# Se importan las librerías
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
### DO_YSI_1100ft(mg/L) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['DO_YSI_1100ft(mg/L)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("DO_YSI_1100ft(mg/L):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# DO_YSI_1100ft(mg/L):
# Coeficiente de determinación: 0.00010861512093574
# Intercepto: 8.71855317010706
# Pendiente: [-0.03001392]

# %%
### ORP_YSI_1100ft(mV) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['ORP_YSI_1100ft(mV)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("ORP_YSI_1100ft(mV):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# ORP_YSI_1100ft(mV):
# Coeficiente de determinación: 0.20256808729200693
# Intercepto: 737.7082553267362
# Pendiente: [2.63482214]

# %%
### chloride_80ft(mg/L) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['chloride_80ft(mg/L)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("chloride_80ft(mg/L):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# chloride_80ft(mg/L):
# Coeficiente de determinación: 1.3037861334996848e-05
# Intercepto: 27.416673150331885
# Pendiente: [0.00813599]

# %%
### chloride_1100ft(mg/L) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['chloride_1100ft(mg/L)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("chloride_1100ft(mg/L):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# chloride_1100ft(mg/L):
# Coeficiente de determinación: 0.0037321506642700175
# Intercepto: 33.64509417523727
# Pendiente: [-0.22585801]

# %%
### pH_YSI_1100ft ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['pH_YSI_1100ft'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("pH_YSI_1100ft:")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# pH_YSI_1100ft:
# Coeficiente de determinación: 0.2168146122030138
# Intercepto: 8.828896115474079
# Pendiente: [-0.01419564]

# %%
### FreeClorine_ATI_80ft(PPM) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['FreeClorine_ATI_80ft(PPM)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("FreeClorine_ATI_80ft(PPM):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# FreeClorine_ATI_80ft(PPM):
# Coeficiente de determinación: 0.011244203560033972
# Intercepto: 1.0334232536652967
# Pendiente: [-0.00232225]

# %%
### FreeClorine_ATI_1100ft(PPM) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['FreeClorine_ATI_1100ft(PPM)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("FreeClorine_ATI_1100ft(PPM):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# FreeClorine_ATI_1100ft(PPM):
# Coeficiente de determinación: 0.09172931760236003
# Intercepto: 0.9591121430944912
# Pendiente: [-0.01020613]

# %%
### CL2_80ft(PPM) ###

# Se cargan los datos
x = np.array(data['concentration']).reshape((-1, 1))
y = np.array(data['CL2_80ft(PPM)'])

# Se genera la predicción
model = LinearRegression()
model.fit(x, y)

# Se imprimen los resultados
print("CL2_80ft(PPM):")
r2 = model.score(x, y)
print(f"Coeficiente de determinación: {r2}")
intercepto = model.intercept_
print(f"Intercepto: {intercepto}")
pendiente = model.coef_
print(f"Pendiente: {pendiente}")
# Out:
# CL2_80ft(PPM):
# Coeficiente de determinación: 0.013964822991778925
# Intercepto: 1.1385062040571532
# Pendiente: [0.00404263]
